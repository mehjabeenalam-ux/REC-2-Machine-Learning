# %% [markdown]
# <a href="https://colab.research.google.com/github/mehjabeenalam-ux/REC-2-Machine-Learning/blob/main/Pandas_EDA_MiniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Pandas Module

# %%
import pandas as pd

# %% [markdown]
# Step 1: Data Loading: Load data from CSV, Excel, SQL, etc., into a DataFrame

# %%
pd.read_csv("/data.csv")  #Reads CSV File
df = pd.read_csv("/data.csv")
print(df)
# Out:
#          Date Category  Value   Product  Sales Region
# 0    1/1/2023        A   28.0  Product1  754.0   East
# 1    1/2/2023        B   39.0  Product3  110.0  North
# 2    1/3/2023        C   32.0  Product2  398.0   East
# 3    1/4/2023        B    8.0  Product1  522.0   East
# 4    1/5/2023        B   26.0  Product3  869.0  North
# 5    1/6/2023        B   54.0  Product3  192.0   West
# 6    1/7/2023        A   16.0  Product1  936.0   East
# 7    1/8/2023        C   89.0  Product1  488.0   West
# 8    1/9/2023        C   37.0  Product3  772.0   West
# 9   1/10/2023        A   22.0  Product2  834.0   West
# 10  1/11/2023        B    7.0  Product1  842.0  North
# 11  1/12/2023        B   60.0  Product2    NaN   West
# 12  1/13/2023        A   70.0  Product3  628.0  South
# 13  1/14/2023        A   69.0  Product1  423.0   East
# 14  1/15/2023        A   47.0  Product2  893.0   West
# 15  1/16/2023        C    NaN  Product1  895.0  North
# ...

# %% [markdown]
# Step 2 Data Overview: Get quick insights about shape, columns, types, and first/last rows.
#
# It is used for understanding dataset size, features, and data types before feature engineering.

# %% [markdown]
# Display first 5 rows

# %%
print(df.head(5))
# Out:
#        Date Category  Value   Product  Sales Region
# 0  1/1/2023        A   28.0  Product1  754.0   East
# 1  1/2/2023        B   39.0  Product3  110.0  North
# 2  1/3/2023        C   32.0  Product2  398.0   East
# 3  1/4/2023        B    8.0  Product1  522.0   East
# 4  1/5/2023        B   26.0  Product3  869.0  North

# %% [markdown]
# Displays last 5 rows (default=5)

# %%
print(df.tail(5))
# Out:
#          Date Category  Value   Product  Sales Region
# 45  2/15/2023        B   99.0  Product2  599.0   West
# 46  2/16/2023        B    6.0  Product1  938.0  South
# 47  2/17/2023        B   69.0  Product3  143.0   West
# 48  2/18/2023        C   65.0  Product3  182.0  North
# 49  2/19/2023        C   11.0  Product3  708.0  North

# %% [markdown]
# Data about Number of Rows and Columns

# %%
print(df.shape) #Returns rows & columns
# Out:
# (50, 6)

# %% [markdown]
#  Column Data Types and Memory Usage

# %%
print(df.info) #Returns columns data types & memory usage
# Out:
# <bound method DataFrame.info of          Date Category  Value   Product  Sales Region
# 0    1/1/2023        A   28.0  Product1  754.0   East
# 1    1/2/2023        B   39.0  Product3  110.0  North
# 2    1/3/2023        C   32.0  Product2  398.0   East
# 3    1/4/2023        B    8.0  Product1  522.0   East
# 4    1/5/2023        B   26.0  Product3  869.0  North
# 5    1/6/2023        B   54.0  Product3  192.0   West
# 6    1/7/2023        A   16.0  Product1  936.0   East
# 7    1/8/2023        C   89.0  Product1  488.0   West
# 8    1/9/2023        C   37.0  Product3  772.0   West
# 9   1/10/2023        A   22.0  Product2  834.0   West
# 10  1/11/2023        B    7.0  Product1  842.0  North
# 11  1/12/2023        B   60.0  Product2    NaN   West
# 12  1/13/2023        A   70.0  Product3  628.0  South
# 13  1/14/2023        A   69.0  Product1  423.0   East
# 14  1/15/2023        A   47.0  Product2  893.0   West
# 15  1/16/2023        C    NaN  Product1  895.0  North
# ...

# %% [markdown]
# List all columns names

# %%
print(df.columns)
# Out:
# Index(['Date', 'Category', 'Value', 'Product', 'Sales', 'Region'], dtype='object')

# %% [markdown]
# Show Index Range

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %% [markdown]
# Shows Data Types of all columns

# %%
print(df.dtypes)
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %% [markdown]
# Summary Statistics of numerical columns

# %%
print(df.describe)

# print(df.describe(include=all)) #Summary Statistics of all columns
# Out:
# <bound method NDFrame.describe of          Date Category  Value   Product  Sales Region
# 0    1/1/2023        A   28.0  Product1  754.0   East
# 1    1/2/2023        B   39.0  Product3  110.0  North
# 2    1/3/2023        C   32.0  Product2  398.0   East
# 3    1/4/2023        B    8.0  Product1  522.0   East
# 4    1/5/2023        B   26.0  Product3  869.0  North
# 5    1/6/2023        B   54.0  Product3  192.0   West
# 6    1/7/2023        A   16.0  Product1  936.0   East
# 7    1/8/2023        C   89.0  Product1  488.0   West
# 8    1/9/2023        C   37.0  Product3  772.0   West
# 9   1/10/2023        A   22.0  Product2  834.0   West
# 10  1/11/2023        B    7.0  Product1  842.0  North
# 11  1/12/2023        B   60.0  Product2    NaN   West
# 12  1/13/2023        A   70.0  Product3  628.0  South
# 13  1/14/2023        A   69.0  Product1  423.0   East
# 14  1/15/2023        A   47.0  Product2  893.0   West
# 15  1/16/2023        C    NaN  Product1  895.0  North
# ...
